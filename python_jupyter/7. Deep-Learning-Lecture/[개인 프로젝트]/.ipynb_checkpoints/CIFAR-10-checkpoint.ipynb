# %% [markdown]
# - http://solarisailab.com/archives/2325

# %%
import tensorflow as tf
import numpy as np

# %%
# CIFAR-10 데이터를 다운로드 받기 위한 keras의 helper 함수인 load_data함수를 임포트한다.
from tensorflow.keras.datasets.cifar10 import load_data

# %%
# 다음 배치를 읽어오기 위한 next_batch 유틸리티 함수를 정의한다.
# num : 개수 만큼의 랜덤한 샘플들과 레이블들을 리턴한다.
def next_batch(num,data,labels):
    idx = np.arange(0,len(data))
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i] for i in idx]
    labels_shuffle = [labels[ i] for i in idx]
    
    return np.asarray(data_shuffle),np.asarray(labels_shuffle)

# %%
# CNN 모델을 정의합니다. 
def build_CNN_classifier(x):
  # 입력 이미지
  x_image = x

  # 첫번째 convolutional layer - 하나의 grayscale 이미지를 64개의 특징들(feature)으로 맵핑(maping)합니다.
  W_conv1 = tf.Variable(tf.truncated_normal(shape=[5, 5, 3, 64], stddev=5e-2))
  b_conv1 = tf.Variable(tf.constant(0.1, shape=[64]))
  h_conv1 = tf.nn.relu(tf.nn.conv2d(x_image, W_conv1, strides=[1, 1, 1, 1], padding='SAME') + b_conv1)

  # 첫번째 Pooling layer
  h_pool1 = tf.nn.max_pool(h_conv1, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='SAME')

  # 두번째 convolutional layer - 32개의 특징들(feature)을 64개의 특징들(feature)로 맵핑(maping)합니다.
  W_conv2 = tf.Variable(tf.truncated_normal(shape=[5, 5, 64, 64], stddev=5e-2))
  b_conv2 = tf.Variable(tf.constant(0.1, shape=[64]))
  h_conv2 = tf.nn.relu(tf.nn.conv2d(h_pool1, W_conv2, strides=[1, 1, 1, 1], padding='SAME') + b_conv2)

  # 두번째 pooling layer.
  h_pool2 = tf.nn.max_pool(h_conv2, ksize=[1, 3, 3, 1], strides=[1, 2, 2, 1], padding='SAME')

  # 세번째 convolutional layer
  W_conv3 = tf.Variable(tf.truncated_normal(shape=[3, 3, 64, 128], stddev=5e-2))
  b_conv3 = tf.Variable(tf.constant(0.1, shape=[128]))
  h_conv3 = tf.nn.relu(tf.nn.conv2d(h_pool2, W_conv3, strides=[1, 1, 1, 1], padding='SAME') + b_conv3)

  # 네번째 convolutional layer
  W_conv4 = tf.Variable(tf.truncated_normal(shape=[3, 3, 128, 128], stddev=5e-2))
  b_conv4 = tf.Variable(tf.constant(0.1, shape=[128])) 
  h_conv4 = tf.nn.relu(tf.nn.conv2d(h_conv3, W_conv4, strides=[1, 1, 1, 1], padding='SAME') + b_conv4)

  # 다섯번째 convolutional layer
  W_conv5 = tf.Variable(tf.truncated_normal(shape=[3, 3, 128, 128], stddev=5e-2))
  b_conv5 = tf.Variable(tf.constant(0.1, shape=[128]))
  h_conv5 = tf.nn.relu(tf.nn.conv2d(h_conv4, W_conv5, strides=[1, 1, 1, 1], padding='SAME') + b_conv5)

  # Fully Connected Layer 1 - 2번의 downsampling 이후에, 우리의 32x32 이미지는 8x8x128 특징맵(feature map)이 됩니다.
  # 이를 384개의 특징들로 맵핑(maping)합니다.
  W_fc1 = tf.Variable(tf.truncated_normal(shape=[8 * 8 * 128, 384], stddev=5e-2))
  b_fc1 = tf.Variable(tf.constant(0.1, shape=[384]))

  h_conv5_flat = tf.reshape(h_conv5, [-1, 8*8*128])
  h_fc1 = tf.nn.relu(tf.matmul(h_conv5_flat, W_fc1) + b_fc1)

  # Dropout - 모델의 복잡도를 컨트롤합니다. 특징들의 co-adaptation을 방지합니다.
  h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob) 

  # Fully Connected Layer 2 - 384개의 특징들(feature)을 10개의 클래스-airplane, automobile, bird...-로 맵핑(maping)합니다.
  W_fc2 = tf.Variable(tf.truncated_normal(shape=[384, 10], stddev=5e-2))
  b_fc2 = tf.Variable(tf.constant(0.1, shape=[10]))
  logits = tf.matmul(h_fc1_drop,W_fc2) + b_fc2
  y_pred = tf.nn.softmax(logits)

  return y_pred, logits

# 인풋 아웃풋 데이터, 드롭아웃 확률을 입력받기위한 플레이스홀더를 정의합니다.
x = tf.placeholder(tf.float32, shape=[None, 32, 32, 3])
y = tf.placeholder(tf.float32, shape=[None, 10])
keep_prob = tf.placeholder(tf.float32)

# CIFAR-10 데이터를 다운로드하고 데이터를 불러옵니다.
(x_train, y_train), (x_test, y_test) = load_data()
# scalar 형태의 레이블(0~9)을 One-hot Encoding 형태로 변환합니다.
y_train_one_hot = tf.squeeze(tf.one_hot(y_train, 10),axis=1)
y_test_one_hot = tf.squeeze(tf.one_hot(y_test, 10),axis=1)

# Convolutional Neural Networks(CNN) 그래프를 생성합니다.
y_pred, logits = build_CNN_classifier(x)

# Cross Entropy를 비용함수(loss function)으로 정의하고, RMSPropOptimizer를 이용해서 비용 함수를 최소화합니다.
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=logits))
train_step = tf.train.RMSPropOptimizer(1e-3).minimize(loss)

# 정확도를 계산하는 연산을 추가합니다.
correct_prediction = tf.equal(tf.argmax(y_pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# 세션을 열어 실제 학습을 진행합니다.
with tf.Session() as sess:
  # 모든 변수들을 초기화한다. 
  sess.run(tf.global_variables_initializer())
  
  # 10000 Step만큼 최적화를 수행합니다.
  for i in range(10000):
    batch = next_batch(128, x_train, y_train_one_hot.eval())

    # 100 Step마다 training 데이터셋에 대한 정확도와 loss를 출력합니다.
    if i % 100 == 0:
      train_accuracy = accuracy.eval(feed_dict={x: batch[0], y: batch[1], keep_prob: 1.0})
      loss_print = loss.eval(feed_dict={x: batch[0], y: batch[1], keep_prob: 1.0})

      print("반복(Epoch): %d, 트레이닝 데이터 정확도: %f, 손실 함수(loss): %f" % (i, train_accuracy, loss_print))
    # 20% 확률의 Dropout을 이용해서 학습을 진행합니다.
    sess.run(train_step, feed_dict={x: batch[0], y: batch[1], keep_prob: 0.8})

  # 학습이 끝나면 테스트 데이터(10000개)에 대한 정확도를 출력합니다.  
  test_accuracy = 0.0  
  for i in range(10):
    test_batch = next_batch(1000, x_test, y_test_one_hot.eval())
    test_accuracy = test_accuracy + accuracy.eval(feed_dict={x: test_batch[0], y: test_batch[1], keep_prob: 1.0})
  test_accuracy = test_accuracy / 10;
  print("테스트 데이터 정확도: %f" % test_accuracy)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0820 17:29:46.248726  1236 deprecation.py:506] From <ipython-input-8-73e5fe5fe745>:46: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0820 17:29:46.281230  1236 deprecation.py:323] From <ipython-input-8-73e5fe5fe745>:71: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0820 17:29:46.968317  1236 deprecation.py:506] From C:\Users\709-000\Anaconda3\lib\site-packages\tensorflow\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 반복(Epoch): 0, 트레이닝 데이터 정확도: 0.101562, 손실 함수(loss): 147.993912
# 반복(Epoch): 100, 트레이닝 데이터 정확도: 0.164062, 손실 함수(loss): 2.174567
# 반복(Epoch): 200, 트레이닝 데이터 정확도: 0.195312, 손실 함수(loss): 2.454833
# 반복(Epoch): 300, 트레이닝 데이터 정확도: 0.281250, 손실 함수(loss): 1.915067
# 반복(Epoch): 400, 트레이닝 데이터 정확도: 0.367188, 손실 함수(loss): 1.588519
# 반복(Epoch): 500, 트레이닝 데이터 정확도: 0.343750, 손실 함수(loss): 1.706578
# 반복(Epoch): 600, 트레이닝 데이터 정확도: 0.460938, 손실 함수(loss): 1.380122
# 반복(Epoch): 700, 트레이닝 데이터 정확도: 0.523438, 손실 함수(loss): 1.362216
# 반복(Epoch): 800, 트레이닝 데이터 정확도: 0.500000, 손실 함수(loss): 1.404185
# 반복(Epoch): 900, 트레이닝 데이터 정확도: 0.515625, 손실 함수(loss): 1.453928
# 반복(Epoch): 1000, 트레이닝 데이터 정확도: 0.593750, 손실 함수(loss): 1.071321
# 반복(Epoch): 1100, 트레이닝 데이터 정확도: 0.578125, 손실 함수(loss): 1.180943
# 반복(Epoch): 1200, 트레이닝 데이터 정확도: 0.562500, 손실 함수(loss): 1.259060
# 반복(Epoch): 1300, 트레이닝 데이터 정확도: 0.632812, 손실 함수(loss): 1.168186
# 반복(Epoch): 1400, 트레이닝 데이터 정확도: 0.531250, 손실 함수(loss): 1.335221
# 반복(Epoch): 1500, 트레이닝 데이터 정확도: 0.585938, 손실 함수(loss): 1.105842
# 반복(Epoch): 1600, 트레이닝 데이터 정확도: 0.656250, 손실 함수(loss): 0.994887
# 반복(Epoch): 1700, 트레이닝 데이터 정확도: 0.632812, 손실 함수(loss): 1.079525
# 반복(Epoch): 1800, 트레이닝 데이터 정확도: 0.554688, 손실 함수(loss): 1.147431
# 반복(Epoch): 1900, 트레이닝 데이터 정확도: 0.632812, 손실 함수(loss): 1.131130
# 반복(Epoch): 2000, 트레이닝 데이터 정확도: 0.601562, 손실 함수(loss): 1.070811
# 반복(Epoch): 2100, 트레이닝 데이터 정확도: 0.562500, 손실 함수(loss): 1.053221
# 반복(Epoch): 2200, 트레이닝 데이터 정확도: 0.679688, 손실 함수(loss): 1.025853
# 반복(Epoch): 2300, 트레이닝 데이터 정확도: 0.750000, 손실 함수(loss): 0.860844
# 반복(Epoch): 2400, 트레이닝 데이터 정확도: 0.585938, 손실 함수(loss): 1.243436
# 반복(Epoch): 2500, 트레이닝 데이터 정확도: 0.656250, 손실 함수(loss): 1.014363
# 반복(Epoch): 2600, 트레이닝 데이터 정확도: 0.609375, 손실 함수(loss): 1.011159
# 반복(Epoch): 2700, 트레이닝 데이터 정확도: 0.679688, 손실 함수(loss): 0.998135
# 반복(Epoch): 2800, 트레이닝 데이터 정확도: 0.734375, 손실 함수(loss): 0.857878
# 반복(Epoch): 2900, 트레이닝 데이터 정확도: 0.664062, 손실 함수(loss): 0.925325
# 반복(Epoch): 3000, 트레이닝 데이터 정확도: 0.656250, 손실 함수(loss): 0.921808
# 반복(Epoch): 3100, 트레이닝 데이터 정확도: 0.664062, 손실 함수(loss): 0.888189
# 반복(Epoch): 3200, 트레이닝 데이터 정확도: 0.687500, 손실 함수(loss): 0.932465
# 반복(Epoch): 3300, 트레이닝 데이터 정확도: 0.679688, 손실 함수(loss): 1.006645
# 반복(Epoch): 3400, 트레이닝 데이터 정확도: 0.765625, 손실 함수(loss): 0.674051
# 반복(Epoch): 3500, 트레이닝 데이터 정확도: 0.703125, 손실 함수(loss): 1.022883
# 반복(Epoch): 3600, 트레이닝 데이터 정확도: 0.687500, 손실 함수(loss): 0.783031
# 반복(Epoch): 3700, 트레이닝 데이터 정확도: 0.617188, 손실 함수(loss): 0.954000
# 반복(Epoch): 3800, 트레이닝 데이터 정확도: 0.710938, 손실 함수(loss): 0.763521
# 반복(Epoch): 3900, 트레이닝 데이터 정확도: 0.718750, 손실 함수(loss): 0.949514
# 반복(Epoch): 4000, 트레이닝 데이터 정확도: 0.687500, 손실 함수(loss): 0.894587
# 반복(Epoch): 4100, 트레이닝 데이터 정확도: 0.742188, 손실 함수(loss): 0.805602
# 반복(Epoch): 4200, 트레이닝 데이터 정확도: 0.765625, 손실 함수(loss): 0.852308
# 반복(Epoch): 4300, 트레이닝 데이터 정확도: 0.742188, 손실 함수(loss): 0.772582
# 반복(Epoch): 4400, 트레이닝 데이터 정확도: 0.648438, 손실 함수(loss): 1.067020
# 반복(Epoch): 4500, 트레이닝 데이터 정확도: 0.640625, 손실 함수(loss): 0.902354
# 반복(Epoch): 4600, 트레이닝 데이터 정확도: 0.664062, 손실 함수(loss): 0.903236
# 반복(Epoch): 4700, 트레이닝 데이터 정확도: 0.671875, 손실 함수(loss): 1.004145
# 반복(Epoch): 4800, 트레이닝 데이터 정확도: 0.742188, 손실 함수(loss): 0.783223
# 반복(Epoch): 4900, 트레이닝 데이터 정확도: 0.734375, 손실 함수(loss): 0.742468
# 반복(Epoch): 5000, 트레이닝 데이터 정확도: 0.632812, 손실 함수(loss): 1.116690
# 반복(Epoch): 5100, 트레이닝 데이터 정확도: 0.765625, 손실 함수(loss): 0.865602
# 반복(Epoch): 5200, 트레이닝 데이터 정확도: 0.750000, 손실 함수(loss): 0.683939
# 반복(Epoch): 5300, 트레이닝 데이터 정확도: 0.726562, 손실 함수(loss): 0.784157
# 반복(Epoch): 5400, 트레이닝 데이터 정확도: 0.734375, 손실 함수(loss): 0.898330
# 반복(Epoch): 5500, 트레이닝 데이터 정확도: 0.671875, 손실 함수(loss): 0.968854
# 반복(Epoch): 5600, 트레이닝 데이터 정확도: 0.664062, 손실 함수(loss): 0.979884
# 반복(Epoch): 5700, 트레이닝 데이터 정확도: 0.703125, 손실 함수(loss): 0.838957
# 반복(Epoch): 5800, 트레이닝 데이터 정확도: 0.656250, 손실 함수(loss): 0.968112
# 반복(Epoch): 5900, 트레이닝 데이터 정확도: 0.703125, 손실 함수(loss): 0.757363
# 반복(Epoch): 6000, 트레이닝 데이터 정확도: 0.703125, 손실 함수(loss): 0.809492
# 반복(Epoch): 6100, 트레이닝 데이터 정확도: 0.718750, 손실 함수(loss): 0.903362
# 반복(Epoch): 6200, 트레이닝 데이터 정확도: 0.687500, 손실 함수(loss): 0.819058
# 반복(Epoch): 6300, 트레이닝 데이터 정확도: 0.625000, 손실 함수(loss): 1.034343
# 반복(Epoch): 6400, 트레이닝 데이터 정확도: 0.546875, 손실 함수(loss): 1.423380
# 반복(Epoch): 6500, 트레이닝 데이터 정확도: 0.687500, 손실 함수(loss): 1.282705
# 반복(Epoch): 6600, 트레이닝 데이터 정확도: 0.656250, 손실 함수(loss): 0.884745
# 반복(Epoch): 6700, 트레이닝 데이터 정확도: 0.765625, 손실 함수(loss): 0.712911
# 반복(Epoch): 6800, 트레이닝 데이터 정확도: 0.687500, 손실 함수(loss): 0.923290
# 반복(Epoch): 6900, 트레이닝 데이터 정확도: 0.625000, 손실 함수(loss): 1.075520
# 반복(Epoch): 7000, 트레이닝 데이터 정확도: 0.710938, 손실 함수(loss): 0.876460
# 반복(Epoch): 7100, 트레이닝 데이터 정확도: 0.734375, 손실 함수(loss): 0.854150
# 반복(Epoch): 7200, 트레이닝 데이터 정확도: 0.742188, 손실 함수(loss): 0.730340
# 반복(Epoch): 7300, 트레이닝 데이터 정확도: 0.609375, 손실 함수(loss): 1.007329
# 반복(Epoch): 7400, 트레이닝 데이터 정확도: 0.617188, 손실 함수(loss): 1.066493
# 반복(Epoch): 7500, 트레이닝 데이터 정확도: 0.609375, 손실 함수(loss): 1.005760
# 반복(Epoch): 7600, 트레이닝 데이터 정확도: 0.703125, 손실 함수(loss): 0.923218
# 반복(Epoch): 7700, 트레이닝 데이터 정확도: 0.679688, 손실 함수(loss): 0.899640
# 반복(Epoch): 7800, 트레이닝 데이터 정확도: 0.757812, 손실 함수(loss): 0.746278
