# %%
#one-hot-encoding을 써야할거여~ 등급맞추기

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy  as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
df_pre = pd.read_csv('../dataset/wine.csv',header=None)
df = df_pre.sample(frac=0.15) # 15%만 랜덤으로 불러온다.
dataset = df.values
X = dataset[:,0:11]
Y = dataset[:,11]

# %%
model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %%
# 모델 저장 폴더 만들기
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
    
modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# %%
# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss',
                              verbose=1, save_best_only=True)

# %%
# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss',patience=100)

# %%
history = model.fit(X,Y,validation_split=0.2, epochs=3500, batch_size=500,
         verbose=0, callbacks=[early_stopping_callback,checkpointer])
# Out:
# W0812 16:14:52.857404  4796 deprecation_wrapper.py:119] From C:\Users\709-000\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 00001: val_loss improved from inf to 0.49246, saving model to ./model/01-0.4925.hdf5
#
# Epoch 00002: val_loss improved from 0.49246 to 0.46745, saving model to ./model/02-0.4674.hdf5
#
# Epoch 00003: val_loss improved from 0.46745 to 0.44050, saving model to ./model/03-0.4405.hdf5
#
# Epoch 00004: val_loss improved from 0.44050 to 0.42319, saving model to ./model/04-0.4232.hdf5
#
# Epoch 00005: val_loss improved from 0.42319 to 0.41159, saving model to ./model/05-0.4116.hdf5
#
# Epoch 00006: val_loss improved from 0.41159 to 0.39826, saving model to ./model/06-0.3983.hdf5
#
# Epoch 00007: val_loss improved from 0.39826 to 0.38853, saving model to ./model/07-0.3885.hdf5
#
# Epoch 00008: val_loss improved from 0.38853 to 0.38116, saving model to ./model/08-0.3812.hdf5
#
# Epoch 00009: val_loss improved from 0.38116 to 0.37470, saving model to ./model/09-0.3747.hdf5
#
# Epoch 00010: val_loss improved from 0.37470 to 0.36824, saving model to ./model/10-0.3682.hdf5
#
# Epoch 00011: val_loss improved from 0.36824 to 0.36160, saving model to ./model/11-0.3616.hdf5
#
# Epoch 00012: val_loss improved from 0.36160 to 0.35565, saving model to ./model/12-0.3557.hdf5
#
# Epoch 00013: val_loss improved from 0.35565 to 0.35060, saving model to ./model/13-0.3506.hdf5
#
# Epoch 00014: val_loss improved from 0.35060 to 0.34587, saving model to ./model/14-0.3459.hdf5
#
# Epoch 00015: val_loss improved from 0.34587 to 0.34034, saving model to ./model/15-0.3403.hdf5
#
# Epoch 00016: val_loss improved from 0.34034 to 0.33487, saving model to ./model/16-0.3349.hdf5
#
# Epoch 00017: val_loss improved from 0.33487 to 0.33015, saving model to ./model/17-0.3302.hdf5
#
# Epoch 00018: val_loss improved from 0.33015 to 0.32609, saving model to ./model/18-0.3261.hdf5
#
# Epoch 00019: val_loss improved from 0.32609 to 0.32412, saving model to ./model/19-0.3241.hdf5
#
# Epoch 00020: val_loss improved from 0.32412 to 0.32036, saving model to ./model/20-0.3204.hdf5
#
# Epoch 00021: val_loss improved from 0.32036 to 0.31351, saving model to ./model/21-0.3135.hdf5
#
# Epoch 00022: val_loss improved from 0.31351 to 0.30885, saving model to ./model/22-0.3088.hdf5
#
# Epoch 00023: val_loss improved from 0.30885 to 0.30480, saving model to ./model/23-0.3048.hdf5
#
# Epoch 00024: val_loss improved from 0.30480 to 0.30147, saving model to ./model/24-0.3015.hdf5
#
# Epoch 00025: val_loss improved from 0.30147 to 0.29875, saving model to ./model/25-0.2987.hdf5
#
# Epoch 00026: val_loss improved from 0.29875 to 0.29396, saving model to ./model/26-0.2940.hdf5
#
# Epoch 00027: val_loss improved from 0.29396 to 0.28850, saving model to ./model/27-0.2885.hdf5
#
# Epoch 00028: val_loss improved from 0.28850 to 0.28418, saving model to ./model/28-0.2842.hdf5
#
# Epoch 00029: val_loss improved from 0.28418 to 0.27963, saving model to ./model/29-0.2796.hdf5
#
# Epoch 00030: val_loss improved from 0.27963 to 0.27691, saving model to ./model/30-0.2769.hdf5
#
# Epoch 00031: val_loss improved from 0.27691 to 0.27240, saving model to ./model/31-0.2724.hdf5
#
# Epoch 00032: val_loss improved from 0.27240 to 0.26779, saving model to ./model/32-0.2678.hdf5
#
# Epoch 00033: val_loss improved from 0.26779 to 0.26406, saving model to ./model/33-0.2641.hdf5
#
# Epoch 00034: val_loss improved from 0.26406 to 0.26073, saving model to ./model/34-0.2607.hdf5
#
# Epoch 00035: val_loss improved from 0.26073 to 0.25921, saving model to ./model/35-0.2592.hdf5
#
# Epoch 00036: val_loss improved from 0.25921 to 0.25550, saving model to ./model/36-0.2555.hdf5
#
# Epoch 00037: val_loss improved from 0.25550 to 0.25218, saving model to ./model/37-0.2522.hdf5
#
# Epoch 00038: val_loss improved from 0.25218 to 0.24975, saving model to ./model/38-0.2497.hdf5
#
# Epoch 00039: val_loss improved from 0.24975 to 0.24759, saving model to ./model/39-0.2476.hdf5
#
# Epoch 00040: val_loss improved from 0.24759 to 0.24570, saving model to ./model/40-0.2457.hdf5
#
# Epoch 00041: val_loss improved from 0.24570 to 0.24461, saving model to ./model/41-0.2446.hdf5
#
# Epoch 00042: val_loss improved from 0.24461 to 0.24227, saving model to ./model/42-0.2423.hdf5
#
# Epoch 00043: val_loss improved from 0.24227 to 0.24049, saving model to ./model/43-0.2405.hdf5
#
# Epoch 00044: val_loss improved from 0.24049 to 0.23866, saving model to ./model/44-0.2387.hdf5
#
# Epoch 00045: val_loss improved from 0.23866 to 0.23811, saving model to ./model/45-0.2381.hdf5
#
# Epoch 00046: val_loss improved from 0.23811 to 0.23795, saving model to ./model/46-0.2379.hdf5
#
# Epoch 00047: val_loss improved from 0.23795 to 0.23524, saving model to ./model/47-0.2352.hdf5
#
# Epoch 00048: val_loss improved from 0.23524 to 0.23263, saving model to ./model/48-0.2326.hdf5
#
# Epoch 00049: val_loss improved from 0.23263 to 0.23112, saving model to ./model/49-0.2311.hdf5
#
# Epoch 00050: val_loss improved from 0.23112 to 0.23056, saving model to ./model/50-0.2306.hdf5
#
# Epoch 00051: val_loss improved from 0.23056 to 0.22864, saving model to ./model/51-0.2286.hdf5
#
# Epoch 00052: val_loss improved from 0.22864 to 0.22730, saving model to ./model/52-0.2273.hdf5
#
# Epoch 00053: val_loss improved from 0.22730 to 0.22585, saving model to ./model/53-0.2258.hdf5
#
# Epoch 00054: val_loss improved from 0.22585 to 0.22516, saving model to ./model/54-0.2252.hdf5
#
# Epoch 00055: val_loss improved from 0.22516 to 0.22421, saving model to ./model/55-0.2242.hdf5
#
# Epoch 00056: val_loss improved from 0.22421 to 0.22238, saving model to ./model/56-0.2224.hdf5
#
# Epoch 00057: val_loss improved from 0.22238 to 0.22105, saving model to ./model/57-0.2211.hdf5
#
# Epoch 00058: val_loss improved from 0.22105 to 0.21982, saving model to ./model/58-0.2198.hdf5
#
# Epoch 00059: val_loss improved from 0.21982 to 0.21875, saving model to ./model/59-0.2188.hdf5
#
# Epoch 00060: val_loss did not improve from 0.21875
#
# Epoch 00061: val_loss did not improve from 0.21875
#
# Epoch 00062: val_loss improved from 0.21875 to 0.21632, saving model to ./model/62-0.2163.hdf5
#
# Epoch 00063: val_loss improved from 0.21632 to 0.21408, saving model to ./model/63-0.2141.hdf5
#
# Epoch 00064: val_loss improved from 0.21408 to 0.21303, saving model to ./model/64-0.2130.hdf5
#
# Epoch 00065: val_loss did not improve from 0.21303
#
# Epoch 00066: val_loss improved from 0.21303 to 0.21278, saving model to ./model/66-0.2128.hdf5
#
# Epoch 00067: val_loss improved from 0.21278 to 0.20945, saving model to ./model/67-0.2095.hdf5
#
# Epoch 00068: val_loss improved from 0.20945 to 0.20811, saving model to ./model/68-0.2081.hdf5
#
# Epoch 00069: val_loss improved from 0.20811 to 0.20648, saving model to ./model/69-0.2065.hdf5
#
# Epoch 00070: val_loss did not improve from 0.20648
#
# Epoch 00071: val_loss did not improve from 0.20648
#
# Epoch 00072: val_loss improved from 0.20648 to 0.20374, saving model to ./model/72-0.2037.hdf5
#
# Epoch 00073: val_loss improved from 0.20374 to 0.20087, saving model to ./model/73-0.2009.hdf5
#
# Epoch 00074: val_loss improved from 0.20087 to 0.19976, saving model to ./model/74-0.1998.hdf5
#
# Epoch 00075: val_loss did not improve from 0.19976
#
# Epoch 00076: val_loss did not improve from 0.19976
#
# Epoch 00077: val_loss improved from 0.19976 to 0.19852, saving model to ./model/77-0.1985.hdf5
#
# Epoch 00078: val_loss improved from 0.19852 to 0.19697, saving model to ./model/78-0.1970.hdf5
#
# Epoch 00079: val_loss improved from 0.19697 to 0.19498, saving model to ./model/79-0.1950.hdf5
#
# Epoch 00080: val_loss improved from 0.19498 to 0.19368, saving model to ./model/80-0.1937.hdf5
#
# Epoch 00081: val_loss improved from 0.19368 to 0.19355, saving model to ./model/81-0.1936.hdf5
#
# Epoch 00082: val_loss did not improve from 0.19355
#
# Epoch 00083: val_loss improved from 0.19355 to 0.19239, saving model to ./model/83-0.1924.hdf5
#
# Epoch 00084: val_loss improved from 0.19239 to 0.18946, saving model to ./model/84-0.1895.hdf5
#
# Epoch 00085: val_loss improved from 0.18946 to 0.18856, saving model to ./model/85-0.1886.hdf5
#
# Epoch 00086: val_loss improved from 0.18856 to 0.18823, saving model to ./model/86-0.1882.hdf5
#
# Epoch 00087: val_loss did not improve from 0.18823
#
# Epoch 00088: val_loss did not improve from 0.18823
#
# Epoch 00089: val_loss improved from 0.18823 to 0.18700, saving model to ./model/89-0.1870.hdf5
#
# Epoch 00090: val_loss improved from 0.18700 to 0.18444, saving model to ./model/90-0.1844.hdf5
#
# Epoch 00091: val_loss improved from 0.18444 to 0.18313, saving model to ./model/91-0.1831.hdf5
#
# Epoch 00092: val_loss did not improve from 0.18313
#
# Epoch 00093: val_loss did not improve from 0.18313
#
# Epoch 00094: val_loss did not improve from 0.18313
#
# Epoch 00095: val_loss improved from 0.18313 to 0.18194, saving model to ./model/95-0.1819.hdf5
#
# Epoch 00096: val_loss improved from 0.18194 to 0.18099, saving model to ./model/96-0.1810.hdf5
# Epoch 00097: val_loss improved from 0.18099 to 0.18044, saving model to ./model/97-0.1804.hdf5
#
# Epoch 00098: val_loss improved from 0.18044 to 0.17937, saving model to ./model/98-0.1794.hdf5
#
# Epoch 00099: val_loss improved from 0.17937 to 0.17908, saving model to ./model/99-0.1791.hdf5
#
# Epoch 00100: val_loss improved from 0.17908 to 0.17755, saving model to ./model/100-0.1776.hdf5
#
# Epoch 00101: val_loss improved from 0.17755 to 0.17612, saving model to ./model/101-0.1761.hdf5
#
# Epoch 00102: val_loss improved from 0.17612 to 0.17437, saving model to ./model/102-0.1744.hdf5
#
# Epoch 00103: val_loss improved from 0.17437 to 0.17365, saving model to ./model/103-0.1737.hdf5
#
# Epoch 00104: val_loss did not improve from 0.17365
#
# Epoch 00105: val_loss did not improve from 0.17365
#
# Epoch 00106: val_loss did not improve from 0.17365
#
# Epoch 00107: val_loss improved from 0.17365 to 0.17006, saving model to ./model/107-0.1701.hdf5
#
# Epoch 00108: val_loss improved from 0.17006 to 0.16930, saving model to ./model/108-0.1693.hdf5
#
# Epoch 00109: val_loss did not improve from 0.16930
#
# Epoch 00110: val_loss did not improve from 0.16930
#
# Epoch 00111: val_loss did not improve from 0.16930
#
# Epoch 00112: val_loss improved from 0.16930 to 0.16672, saving model to ./model/112-0.1667.hdf5
#
# Epoch 00113: val_loss improved from 0.16672 to 0.16616, saving model to ./model/113-0.1662.hdf5
#
# Epoch 00114: val_loss did not improve from 0.16616
#
# Epoch 00115: val_loss did not improve from 0.16616
#
# Epoch 00116: val_loss did not improve from 0.16616
#
# Epoch 00117: val_loss improved from 0.16616 to 0.16486, saving model to ./model/117-0.1649.hdf5
#
# Epoch 00118: val_loss improved from 0.16486 to 0.16460, saving model to ./model/118-0.1646.hdf5
#
# Epoch 00119: val_loss did not improve from 0.16460
#
# Epoch 00120: val_loss did not improve from 0.16460
#
# Epoch 00121: val_loss improved from 0.16460 to 0.16399, saving model to ./model/121-0.1640.hdf5
#
# Epoch 00122: val_loss improved from 0.16399 to 0.16060, saving model to ./model/122-0.1606.hdf5
#
# Epoch 00123: val_loss did not improve from 0.16060
#
# Epoch 00124: val_loss did not improve from 0.16060
#
# Epoch 00125: val_loss did not improve from 0.16060
#
# Epoch 00126: val_loss did not improve from 0.16060
#
# Epoch 00127: val_loss improved from 0.16060 to 0.15816, saving model to ./model/127-0.1582.hdf5
#
# Epoch 00128: val_loss did not improve from 0.15816
#
# Epoch 00129: val_loss did not improve from 0.15816
#
# Epoch 00130: val_loss did not improve from 0.15816
#
# Epoch 00131: val_loss did not improve from 0.15816
#
# Epoch 00132: val_loss improved from 0.15816 to 0.15604, saving model to ./model/132-0.1560.hdf5
#
# Epoch 00133: val_loss improved from 0.15604 to 0.15533, saving model to ./model/133-0.1553.hdf5
#
# Epoch 00134: val_loss did not improve from 0.15533
#
# Epoch 00135: val_loss did not improve from 0.15533
#
# Epoch 00136: val_loss improved from 0.15533 to 0.15450, saving model to ./model/136-0.1545.hdf5
#
# Epoch 00137: val_loss improved from 0.15450 to 0.15340, saving model to ./model/137-0.1534.hdf5
#
# Epoch 00138: val_loss did not improve from 0.15340
#
# Epoch 00139: val_loss did not improve from 0.15340
#
# Epoch 00140: val_loss improved from 0.15340 to 0.15227, saving model to ./model/140-0.1523.hdf5
#
# Epoch 00141: val_loss improved from 0.15227 to 0.15121, saving model to ./model/141-0.1512.hdf5
#
# Epoch 00142: val_loss did not improve from 0.15121
#
# Epoch 00143: val_loss did not improve from 0.15121
#
# Epoch 00144: val_loss did not improve from 0.15121
#
# Epoch 00145: val_loss improved from 0.15121 to 0.14916, saving model to ./model/145-0.1492.hdf5
#
# Epoch 00146: val_loss improved from 0.14916 to 0.14877, saving model to ./model/146-0.1488.hdf5
#
# Epoch 00147: val_loss did not improve from 0.14877
#
# Epoch 00148: val_loss did not improve from 0.14877
#
# Epoch 00149: val_loss did not improve from 0.14877
#
# Epoch 00150: val_loss did not improve from 0.14877
#
# Epoch 00151: val_loss did not improve from 0.14877
#
# Epoch 00152: val_loss did not improve from 0.14877
#
# Epoch 00153: val_loss did not improve from 0.14877
#
# Epoch 00154: val_loss improved from 0.14877 to 0.14598, saving model to ./model/154-0.1460.hdf5
#
# Epoch 00155: val_loss improved from 0.14598 to 0.14417, saving model to ./model/155-0.1442.hdf5
#
# Epoch 00156: val_loss did not improve from 0.14417
#
# Epoch 00157: val_loss did not improve from 0.14417
#
# Epoch 00158: val_loss did not improve from 0.14417
#
# Epoch 00159: val_loss did not improve from 0.14417
#
# Epoch 00160: val_loss improved from 0.14417 to 0.14325, saving model to ./model/160-0.1432.hdf5
#
# Epoch 00161: val_loss did not improve from 0.14325
#
# Epoch 00162: val_loss did not improve from 0.14325
#
# Epoch 00163: val_loss improved from 0.14325 to 0.14258, saving model to ./model/163-0.1426.hdf5
#
# Epoch 00164: val_loss improved from 0.14258 to 0.14054, saving model to ./model/164-0.1405.hdf5
#
# Epoch 00165: val_loss did not improve from 0.14054
#
# Epoch 00166: val_loss did not improve from 0.14054
#
# Epoch 00167: val_loss did not improve from 0.14054
#
# Epoch 00168: val_loss improved from 0.14054 to 0.13930, saving model to ./model/168-0.1393.hdf5
#
# Epoch 00169: val_loss improved from 0.13930 to 0.13833, saving model to ./model/169-0.1383.hdf5
#
# Epoch 00170: val_loss did not improve from 0.13833
#
# Epoch 00171: val_loss did not improve from 0.13833
#
# Epoch 00172: val_loss did not improve from 0.13833
#
# Epoch 00173: val_loss did not improve from 0.13833
#
# Epoch 00174: val_loss did not improve from 0.13833
#
# Epoch 00175: val_loss did not improve from 0.13833
#
# Epoch 00176: val_loss improved from 0.13833 to 0.13535, saving model to ./model/176-0.1354.hdf5
#
# Epoch 00177: val_loss did not improve from 0.13535
#
# Epoch 00178: val_loss did not improve from 0.13535
#
# Epoch 00179: val_loss did not improve from 0.13535
#
# Epoch 00180: val_loss did not improve from 0.13535
#
# Epoch 00181: val_loss improved from 0.13535 to 0.13337, saving model to ./model/181-0.1334.hdf5
#
# Epoch 00182: val_loss did not improve from 0.13337
#
# Epoch 00183: val_loss did not improve from 0.13337
#
# Epoch 00184: val_loss did not improve from 0.13337
#
# Epoch 00185: val_loss did not improve from 0.13337
#
# Epoch 00186: val_loss improved from 0.13337 to 0.13259, saving model to ./model/186-0.1326.hdf5
#
# Epoch 00187: val_loss did not improve from 0.13259
#
# Epoch 00188: val_loss did not improve from 0.13259
#
# Epoch 00189: val_loss did not improve from 0.13259
#
# Epoch 00190: val_loss improved from 0.13259 to 0.13047, saving model to ./model/190-0.1305.hdf5
#
# Epoch 00191: val_loss did not improve from 0.13047
#
# Epoch 00192: val_loss did not improve from 0.13047
#
# Epoch 00193: val_loss did not improve from 0.13047
#
# Epoch 00194: val_loss improved from 0.13047 to 0.13020, saving model to ./model/194-0.1302.hdf5
#
# Epoch 00195: val_loss did not improve from 0.13020
#
# Epoch 00196: val_loss did not improve from 0.13020
#
# Epoch 00197: val_loss improved from 0.13020 to 0.12974, saving model to ./model/197-0.1297.hdf5
#
# Epoch 00198: val_loss improved from 0.12974 to 0.12752, saving model to ./model/198-0.1275.hdf5
#
# Epoch 00199: val_loss did not improve from 0.12752
#
# Epoch 00200: val_loss did not improve from 0.12752
#
# Epoch 00201: val_loss did not improve from 0.12752
#
# Epoch 00202: val_loss improved from 0.12752 to 0.12662, saving model to ./model/202-0.1266.hdf5
#
# Epoch 00203: val_loss did not improve from 0.12662
#
# Epoch 00204: val_loss did not improve from 0.12662
#
# Epoch 00205: val_loss did not improve from 0.12662
#
# Epoch 00206: val_loss improved from 0.12662 to 0.12584, saving model to ./model/206-0.1258.hdf5
#
# Epoch 00207: val_loss did not improve from 0.12584
#
# Epoch 00208: val_loss did not improve from 0.12584
#
# Epoch 00209: val_loss did not improve from 0.12584
#
# Epoch 00210: val_loss did not improve from 0.12584
#
# Epoch 00211: val_loss improved from 0.12584 to 0.12510, saving model to ./model/211-0.1251.hdf5
#
# Epoch 00212: val_loss did not improve from 0.12510
#
# Epoch 00213: val_loss did not improve from 0.12510
#
# Epoch 00214: val_loss did not improve from 0.12510
#
# Epoch 00215: val_loss improved from 0.12510 to 0.12364, saving model to ./model/215-0.1236.hdf5
#
# Epoch 00216: val_loss did not improve from 0.12364
#
# Epoch 00217: val_loss did not improve from 0.12364
#
# Epoch 00218: val_loss did not improve from 0.12364
#
# Epoch 00219: val_loss did not improve from 0.12364
#
# Epoch 00220: val_loss did not improve from 0.12364
#
# Epoch 00221: val_loss did not improve from 0.12364
#
# Epoch 00222: val_loss did not improve from 0.12364
#
# Epoch 00223: val_loss did not improve from 0.12364
#
# Epoch 00224: val_loss did not improve from 0.12364
#
# Epoch 00225: val_loss did not improve from 0.12364
#
# Epoch 00226: val_loss did not improve from 0.12364
#
# Epoch 00227: val_loss improved from 0.12364 to 0.12225, saving model to ./model/227-0.1223.hdf5
#
# Epoch 00228: val_loss did not improve from 0.12225
# Epoch 00229: val_loss did not improve from 0.12225
#
# Epoch 00230: val_loss improved from 0.12225 to 0.12090, saving model to ./model/230-0.1209.hdf5
#
# Epoch 00231: val_loss improved from 0.12090 to 0.11969, saving model to ./model/231-0.1197.hdf5
#
# Epoch 00232: val_loss did not improve from 0.11969
#
# Epoch 00233: val_loss did not improve from 0.11969
#
# Epoch 00234: val_loss improved from 0.11969 to 0.11862, saving model to ./model/234-0.1186.hdf5
#
# Epoch 00235: val_loss did not improve from 0.11862
#
# Epoch 00236: val_loss did not improve from 0.11862
#
# Epoch 00237: val_loss did not improve from 0.11862
#
# Epoch 00238: val_loss improved from 0.11862 to 0.11781, saving model to ./model/238-0.1178.hdf5
#
# Epoch 00239: val_loss did not improve from 0.11781
#
# Epoch 00240: val_loss did not improve from 0.11781
#
# Epoch 00241: val_loss did not improve from 0.11781
#
# Epoch 00242: val_loss improved from 0.11781 to 0.11585, saving model to ./model/242-0.1159.hdf5
#
# Epoch 00243: val_loss did not improve from 0.11585
#
# Epoch 00244: val_loss did not improve from 0.11585
#
# Epoch 00245: val_loss did not improve from 0.11585
#
# Epoch 00246: val_loss did not improve from 0.11585
#
# Epoch 00247: val_loss did not improve from 0.11585
#
# Epoch 00248: val_loss did not improve from 0.11585
#
# Epoch 00249: val_loss improved from 0.11585 to 0.11555, saving model to ./model/249-0.1155.hdf5
#
# Epoch 00250: val_loss improved from 0.11555 to 0.11347, saving model to ./model/250-0.1135.hdf5
#
# Epoch 00251: val_loss did not improve from 0.11347
#
# Epoch 00252: val_loss did not improve from 0.11347
#
# Epoch 00253: val_loss did not improve from 0.11347
#
# Epoch 00254: val_loss did not improve from 0.11347
#
# Epoch 00255: val_loss did not improve from 0.11347
#
# Epoch 00256: val_loss did not improve from 0.11347
#
# Epoch 00257: val_loss did not improve from 0.11347
#
# Epoch 00258: val_loss improved from 0.11347 to 0.11281, saving model to ./model/258-0.1128.hdf5
#
# Epoch 00259: val_loss did not improve from 0.11281
#
# Epoch 00260: val_loss did not improve from 0.11281
#
# Epoch 00261: val_loss improved from 0.11281 to 0.11251, saving model to ./model/261-0.1125.hdf5
#
# Epoch 00262: val_loss improved from 0.11251 to 0.11156, saving model to ./model/262-0.1116.hdf5
#
# Epoch 00263: val_loss did not improve from 0.11156
#
# Epoch 00264: val_loss did not improve from 0.11156
#
# Epoch 00265: val_loss did not improve from 0.11156
#
# Epoch 00266: val_loss improved from 0.11156 to 0.10854, saving model to ./model/266-0.1085.hdf5
#
# Epoch 00267: val_loss did not improve from 0.10854
#
# Epoch 00268: val_loss did not improve from 0.10854
#
# Epoch 00269: val_loss did not improve from 0.10854
#
# Epoch 00270: val_loss did not improve from 0.10854
#
# Epoch 00271: val_loss did not improve from 0.10854
#
# Epoch 00272: val_loss did not improve from 0.10854
#
# Epoch 00273: val_loss did not improve from 0.10854
#
# Epoch 00274: val_loss did not improve from 0.10854
#
# Epoch 00275: val_loss did not improve from 0.10854
#
# Epoch 00276: val_loss did not improve from 0.10854
#
# Epoch 00277: val_loss did not improve from 0.10854
#
# Epoch 00278: val_loss did not improve from 0.10854
#
# Epoch 00279: val_loss improved from 0.10854 to 0.10814, saving model to ./model/279-0.1081.hdf5
#
# Epoch 00280: val_loss did not improve from 0.10814
#
# Epoch 00281: val_loss did not improve from 0.10814
#
# Epoch 00282: val_loss did not improve from 0.10814
#
# Epoch 00283: val_loss did not improve from 0.10814
#
# Epoch 00284: val_loss did not improve from 0.10814
#
# Epoch 00285: val_loss did not improve from 0.10814
#
# Epoch 00286: val_loss did not improve from 0.10814
#
# Epoch 00287: val_loss improved from 0.10814 to 0.10612, saving model to ./model/287-0.1061.hdf5
#
# Epoch 00288: val_loss did not improve from 0.10612
#
# Epoch 00289: val_loss did not improve from 0.10612
#
# Epoch 00290: val_loss did not improve from 0.10612
#
# Epoch 00291: val_loss did not improve from 0.10612
#
# Epoch 00292: val_loss improved from 0.10612 to 0.10432, saving model to ./model/292-0.1043.hdf5
#
# Epoch 00293: val_loss did not improve from 0.10432
#
# Epoch 00294: val_loss did not improve from 0.10432
#
# Epoch 00295: val_loss did not improve from 0.10432
#
# Epoch 00296: val_loss did not improve from 0.10432
#
# Epoch 00297: val_loss did not improve from 0.10432
#
# Epoch 00298: val_loss did not improve from 0.10432
#
# Epoch 00299: val_loss improved from 0.10432 to 0.10037, saving model to ./model/299-0.1004.hdf5
#
# Epoch 00300: val_loss did not improve from 0.10037
#
# Epoch 00301: val_loss did not improve from 0.10037
#
# Epoch 00302: val_loss did not improve from 0.10037
#
# Epoch 00303: val_loss did not improve from 0.10037
#
# Epoch 00304: val_loss did not improve from 0.10037
#
# Epoch 00305: val_loss did not improve from 0.10037
#
# Epoch 00306: val_loss improved from 0.10037 to 0.09917, saving model to ./model/306-0.0992.hdf5
#
# Epoch 00307: val_loss did not improve from 0.09917
#
# Epoch 00308: val_loss did not improve from 0.09917
#
# Epoch 00309: val_loss did not improve from 0.09917
#
# Epoch 00310: val_loss improved from 0.09917 to 0.09896, saving model to ./model/310-0.0990.hdf5
#
# Epoch 00311: val_loss did not improve from 0.09896
#
# Epoch 00312: val_loss did not improve from 0.09896
#
# Epoch 00313: val_loss did not improve from 0.09896
#
# Epoch 00314: val_loss did not improve from 0.09896
#
# Epoch 00315: val_loss did not improve from 0.09896
#
# Epoch 00316: val_loss did not improve from 0.09896
#
# Epoch 00317: val_loss did not improve from 0.09896
#
# Epoch 00318: val_loss did not improve from 0.09896
#
# Epoch 00319: val_loss did not improve from 0.09896
#
# Epoch 00320: val_loss improved from 0.09896 to 0.09797, saving model to ./model/320-0.0980.hdf5
#
# Epoch 00321: val_loss did not improve from 0.09797
#
# Epoch 00322: val_loss did not improve from 0.09797
#
# Epoch 00323: val_loss improved from 0.09797 to 0.09627, saving model to ./model/323-0.0963.hdf5
#
# Epoch 00324: val_loss did not improve from 0.09627
#
# Epoch 00325: val_loss did not improve from 0.09627
#
# Epoch 00326: val_loss did not improve from 0.09627
#
# Epoch 00327: val_loss did not improve from 0.09627
#
# Epoch 00328: val_loss did not improve from 0.09627
#
# Epoch 00329: val_loss did not improve from 0.09627
#
# Epoch 00330: val_loss improved from 0.09627 to 0.09422, saving model to ./model/330-0.0942.hdf5
#
# Epoch 00331: val_loss did not improve from 0.09422
#
# Epoch 00332: val_loss did not improve from 0.09422
#
# Epoch 00333: val_loss did not improve from 0.09422
#
# Epoch 00334: val_loss improved from 0.09422 to 0.09397, saving model to ./model/334-0.0940.hdf5
#
# Epoch 00335: val_loss did not improve from 0.09397
#
# Epoch 00336: val_loss did not improve from 0.09397
#
# Epoch 00337: val_loss improved from 0.09397 to 0.09221, saving model to ./model/337-0.0922.hdf5
#
# Epoch 00338: val_loss did not improve from 0.09221
#
# Epoch 00339: val_loss did not improve from 0.09221
#
# Epoch 00340: val_loss did not improve from 0.09221
#
# Epoch 00341: val_loss did not improve from 0.09221
#
# Epoch 00342: val_loss did not improve from 0.09221
#
# Epoch 00343: val_loss did not improve from 0.09221
#
# Epoch 00344: val_loss did not improve from 0.09221
#
# Epoch 00345: val_loss did not improve from 0.09221
#
# Epoch 00346: val_loss did not improve from 0.09221
#
# Epoch 00347: val_loss did not improve from 0.09221
#
# Epoch 00348: val_loss did not improve from 0.09221
#
# Epoch 00349: val_loss did not improve from 0.09221
#
# Epoch 00350: val_loss did not improve from 0.09221
#
# Epoch 00351: val_loss did not improve from 0.09221
#
# Epoch 00352: val_loss did not improve from 0.09221
#
# Epoch 00353: val_loss did not improve from 0.09221
#
# Epoch 00354: val_loss did not improve from 0.09221
#
# Epoch 00355: val_loss did not improve from 0.09221
#
# Epoch 00356: val_loss improved from 0.09221 to 0.09090, saving model to ./model/356-0.0909.hdf5
#
# Epoch 00357: val_loss did not improve from 0.09090
#
# Epoch 00358: val_loss did not improve from 0.09090
#
# Epoch 00359: val_loss did not improve from 0.09090
#
# Epoch 00360: val_loss did not improve from 0.09090
#
# Epoch 00361: val_loss did not improve from 0.09090
#
# Epoch 00362: val_loss improved from 0.09090 to 0.08954, saving model to ./model/362-0.0895.hdf5
#
# Epoch 00363: val_loss did not improve from 0.08954
#
# Epoch 00364: val_loss did not improve from 0.08954
#
# Epoch 00365: val_loss did not improve from 0.08954
#
# Epoch 00366: val_loss did not improve from 0.08954
#
# Epoch 00367: val_loss did not improve from 0.08954
#
# Epoch 00368: val_loss did not improve from 0.08954
#
# Epoch 00369: val_loss did not improve from 0.08954
#
# Epoch 00370: val_loss improved from 0.08954 to 0.08696, saving model to ./model/370-0.0870.hdf5
#
# Epoch 00371: val_loss did not improve from 0.08696
#
# Epoch 00372: val_loss did not improve from 0.08696
#
# Epoch 00373: val_loss did not improve from 0.08696
#
# Epoch 00374: val_loss improved from 0.08696 to 0.08561, saving model to ./model/374-0.0856.hdf5
#
# Epoch 00375: val_loss did not improve from 0.08561
#
# Epoch 00376: val_loss did not improve from 0.08561
#
# Epoch 00377: val_loss did not improve from 0.08561
#
# Epoch 00378: val_loss improved from 0.08561 to 0.08523, saving model to ./model/378-0.0852.hdf5
#
# Epoch 00379: val_loss did not improve from 0.08523
# Epoch 00380: val_loss did not improve from 0.08523
#
# Epoch 00381: val_loss did not improve from 0.08523
#
# Epoch 00382: val_loss improved from 0.08523 to 0.08478, saving model to ./model/382-0.0848.hdf5
#
# Epoch 00383: val_loss did not improve from 0.08478
#
# Epoch 00384: val_loss did not improve from 0.08478
#
# Epoch 00385: val_loss did not improve from 0.08478
#
# Epoch 00386: val_loss improved from 0.08478 to 0.08383, saving model to ./model/386-0.0838.hdf5
#
# Epoch 00387: val_loss did not improve from 0.08383
#
# Epoch 00388: val_loss did not improve from 0.08383
#
# Epoch 00389: val_loss did not improve from 0.08383
#
# Epoch 00390: val_loss improved from 0.08383 to 0.08332, saving model to ./model/390-0.0833.hdf5
#
# Epoch 00391: val_loss did not improve from 0.08332
#
# Epoch 00392: val_loss did not improve from 0.08332
#
# Epoch 00393: val_loss did not improve from 0.08332
#
# Epoch 00394: val_loss did not improve from 0.08332
#
# Epoch 00395: val_loss did not improve from 0.08332
#
# Epoch 00396: val_loss did not improve from 0.08332
#
# Epoch 00397: val_loss improved from 0.08332 to 0.08080, saving model to ./model/397-0.0808.hdf5
#
# Epoch 00398: val_loss did not improve from 0.08080
#
# Epoch 00399: val_loss did not improve from 0.08080
#
# Epoch 00400: val_loss did not improve from 0.08080
#
# Epoch 00401: val_loss did not improve from 0.08080
#
# Epoch 00402: val_loss did not improve from 0.08080
#
# Epoch 00403: val_loss did not improve from 0.08080
#
# Epoch 00404: val_loss did not improve from 0.08080
#
# Epoch 00405: val_loss did not improve from 0.08080
#
# Epoch 00406: val_loss did not improve from 0.08080
#
# Epoch 00407: val_loss improved from 0.08080 to 0.08004, saving model to ./model/407-0.0800.hdf5
#
# Epoch 00408: val_loss did not improve from 0.08004
#
# Epoch 00409: val_loss did not improve from 0.08004
#
# Epoch 00410: val_loss did not improve from 0.08004
#
# Epoch 00411: val_loss did not improve from 0.08004
#
# Epoch 00412: val_loss did not improve from 0.08004
#
# Epoch 00413: val_loss did not improve from 0.08004
#
# Epoch 00414: val_loss did not improve from 0.08004
#
# Epoch 00415: val_loss did not improve from 0.08004
#
# Epoch 00416: val_loss did not improve from 0.08004
#
# Epoch 00417: val_loss did not improve from 0.08004
#
# Epoch 00418: val_loss improved from 0.08004 to 0.07947, saving model to ./model/418-0.0795.hdf5
#
# Epoch 00419: val_loss did not improve from 0.07947
#
# Epoch 00420: val_loss did not improve from 0.07947
#
# Epoch 00421: val_loss improved from 0.07947 to 0.07728, saving model to ./model/421-0.0773.hdf5
#
# Epoch 00422: val_loss did not improve from 0.07728
#
# Epoch 00423: val_loss did not improve from 0.07728
#
# Epoch 00424: val_loss did not improve from 0.07728
#
# Epoch 00425: val_loss improved from 0.07728 to 0.07604, saving model to ./model/425-0.0760.hdf5
#
# Epoch 00426: val_loss did not improve from 0.07604
#
# Epoch 00427: val_loss did not improve from 0.07604
#
# Epoch 00428: val_loss did not improve from 0.07604
#
# Epoch 00429: val_loss improved from 0.07604 to 0.07597, saving model to ./model/429-0.0760.hdf5
#
# Epoch 00430: val_loss did not improve from 0.07597
#
# Epoch 00431: val_loss did not improve from 0.07597
#
# Epoch 00432: val_loss improved from 0.07597 to 0.07586, saving model to ./model/432-0.0759.hdf5
#
# Epoch 00433: val_loss did not improve from 0.07586
#
# Epoch 00434: val_loss did not improve from 0.07586
#
# Epoch 00435: val_loss did not improve from 0.07586
#
# Epoch 00436: val_loss improved from 0.07586 to 0.07583, saving model to ./model/436-0.0758.hdf5
#
# Epoch 00437: val_loss did not improve from 0.07583
#
# Epoch 00438: val_loss did not improve from 0.07583
#
# Epoch 00439: val_loss improved from 0.07583 to 0.07501, saving model to ./model/439-0.0750.hdf5
#
# Epoch 00440: val_loss did not improve from 0.07501
#
# Epoch 00441: val_loss did not improve from 0.07501
#
# Epoch 00442: val_loss did not improve from 0.07501
#
# Epoch 00443: val_loss did not improve from 0.07501
#
# Epoch 00444: val_loss did not improve from 0.07501
#
# Epoch 00445: val_loss did not improve from 0.07501
#
# Epoch 00446: val_loss did not improve from 0.07501
#
# Epoch 00447: val_loss did not improve from 0.07501
#
# Epoch 00448: val_loss improved from 0.07501 to 0.07303, saving model to ./model/448-0.0730.hdf5
#
# Epoch 00449: val_loss did not improve from 0.07303
#
# Epoch 00450: val_loss did not improve from 0.07303
#
# Epoch 00451: val_loss did not improve from 0.07303
#
# Epoch 00452: val_loss did not improve from 0.07303
#
# Epoch 00453: val_loss did not improve from 0.07303
#
# Epoch 00454: val_loss did not improve from 0.07303
#
# Epoch 00455: val_loss did not improve from 0.07303
#
# Epoch 00456: val_loss did not improve from 0.07303
#
# Epoch 00457: val_loss did not improve from 0.07303
#
# Epoch 00458: val_loss did not improve from 0.07303
#
# Epoch 00459: val_loss improved from 0.07303 to 0.07179, saving model to ./model/459-0.0718.hdf5
#
# Epoch 00460: val_loss did not improve from 0.07179
#
# Epoch 00461: val_loss did not improve from 0.07179
#
# Epoch 00462: val_loss did not improve from 0.07179
#
# Epoch 00463: val_loss did not improve from 0.07179
#
# Epoch 00464: val_loss did not improve from 0.07179
#
# Epoch 00465: val_loss did not improve from 0.07179
#
# Epoch 00466: val_loss did not improve from 0.07179
#
# Epoch 00467: val_loss did not improve from 0.07179
#
# Epoch 00468: val_loss did not improve from 0.07179
#
# Epoch 00469: val_loss did not improve from 0.07179
#
# Epoch 00470: val_loss did not improve from 0.07179
#
# Epoch 00471: val_loss did not improve from 0.07179
#
# Epoch 00472: val_loss did not improve from 0.07179
#
# Epoch 00473: val_loss did not improve from 0.07179
#
# Epoch 00474: val_loss did not improve from 0.07179
#
# Epoch 00475: val_loss improved from 0.07179 to 0.07038, saving model to ./model/475-0.0704.hdf5
#
# Epoch 00476: val_loss did not improve from 0.07038
#
# Epoch 00477: val_loss did not improve from 0.07038
#
# Epoch 00478: val_loss did not improve from 0.07038
#
# Epoch 00479: val_loss did not improve from 0.07038
#
# Epoch 00480: val_loss did not improve from 0.07038
#
# Epoch 00481: val_loss did not improve from 0.07038
#
# Epoch 00482: val_loss did not improve from 0.07038
#
# Epoch 00483: val_loss did not improve from 0.07038
#
# Epoch 00484: val_loss did not improve from 0.07038
#
# Epoch 00485: val_loss did not improve from 0.07038
#
# Epoch 00486: val_loss did not improve from 0.07038
#
# Epoch 00487: val_loss did not improve from 0.07038
#
# Epoch 00488: val_loss did not improve from 0.07038
#
# Epoch 00489: val_loss did not improve from 0.07038
#
# Epoch 00490: val_loss did not improve from 0.07038
#
# Epoch 00491: val_loss did not improve from 0.07038
#
# Epoch 00492: val_loss improved from 0.07038 to 0.07016, saving model to ./model/492-0.0702.hdf5
#
# Epoch 00493: val_loss did not improve from 0.07016
#
# Epoch 00494: val_loss did not improve from 0.07016
#
# Epoch 00495: val_loss improved from 0.07016 to 0.07002, saving model to ./model/495-0.0700.hdf5
#
# Epoch 00496: val_loss did not improve from 0.07002
#
# Epoch 00497: val_loss did not improve from 0.07002
#
# Epoch 00498: val_loss improved from 0.07002 to 0.06852, saving model to ./model/498-0.0685.hdf5
#
# Epoch 00499: val_loss did not improve from 0.06852
#
# Epoch 00500: val_loss did not improve from 0.06852
#
# Epoch 00501: val_loss did not improve from 0.06852
#
# Epoch 00502: val_loss improved from 0.06852 to 0.06750, saving model to ./model/502-0.0675.hdf5
#
# Epoch 00503: val_loss did not improve from 0.06750
#
# Epoch 00504: val_loss did not improve from 0.06750
#
# Epoch 00505: val_loss did not improve from 0.06750
#
# Epoch 00506: val_loss improved from 0.06750 to 0.06748, saving model to ./model/506-0.0675.hdf5
#
# Epoch 00507: val_loss did not improve from 0.06748
#
# Epoch 00508: val_loss did not improve from 0.06748
#
# Epoch 00509: val_loss did not improve from 0.06748
#
# Epoch 00510: val_loss did not improve from 0.06748
#
# Epoch 00511: val_loss did not improve from 0.06748
#
# Epoch 00512: val_loss did not improve from 0.06748
#
# Epoch 00513: val_loss did not improve from 0.06748
#
# Epoch 00514: val_loss did not improve from 0.06748
#
# Epoch 00515: val_loss did not improve from 0.06748
#
# Epoch 00516: val_loss improved from 0.06748 to 0.06718, saving model to ./model/516-0.0672.hdf5
#
# Epoch 00517: val_loss did not improve from 0.06718
#
# Epoch 00518: val_loss did not improve from 0.06718
#
# Epoch 00519: val_loss did not improve from 0.06718
#
# Epoch 00520: val_loss did not improve from 0.06718
#
# Epoch 00521: val_loss did not improve from 0.06718
#
# Epoch 00522: val_loss did not improve from 0.06718
#
# Epoch 00523: val_loss improved from 0.06718 to 0.06713, saving model to ./model/523-0.0671.hdf5
#
# Epoch 00524: val_loss did not improve from 0.06713
#
# Epoch 00525: val_loss did not improve from 0.06713
#
# Epoch 00526: val_loss did not improve from 0.06713
#
# Epoch 00527: val_loss improved from 0.06713 to 0.06613, saving model to ./model/527-0.0661.hdf5
#
# Epoch 00528: val_loss did not improve from 0.06613
#
# Epoch 00529: val_loss did not improve from 0.06613
#
# Epoch 00530: val_loss improved from 0.06613 to 0.06566, saving model to ./model/530-0.0657.hdf5
#
# Epoch 00531: val_loss did not improve from 0.06566
#
# Epoch 00532: val_loss did not improve from 0.06566
#
# Epoch 00533: val_loss did not improve from 0.06566
#
# Epoch 00534: val_loss did not improve from 0.06566
#
# Epoch 00535: val_loss did not improve from 0.06566
#
# Epoch 00536: val_loss did not improve from 0.06566
#
# Epoch 00537: val_loss did not improve from 0.06566
#
# Epoch 00538: val_loss did not improve from 0.06566
#
# Epoch 00539: val_loss did not improve from 0.06566
#
# Epoch 00540: val_loss did not improve from 0.06566
#
# Epoch 00541: val_loss did not improve from 0.06566
#
# Epoch 00542: val_loss did not improve from 0.06566
#
# Epoch 00543: val_loss did not improve from 0.06566
#
# Epoch 00544: val_loss did not improve from 0.06566
#
# Epoch 00545: val_loss did not improve from 0.06566
#
# Epoch 00546: val_loss did not improve from 0.06566
#
# Epoch 00547: val_loss did not improve from 0.06566
#
# Epoch 00548: val_loss did not improve from 0.06566
#
# Epoch 00549: val_loss did not improve from 0.06566
#
# Epoch 00550: val_loss did not improve from 0.06566
#
# Epoch 00551: val_loss did not improve from 0.06566
#
# Epoch 00552: val_loss did not improve from 0.06566
#
# Epoch 00553: val_loss did not improve from 0.06566
#
# Epoch 00554: val_loss did not improve from 0.06566
#
# Epoch 00555: val_loss did not improve from 0.06566
#
# Epoch 00556: val_loss did not improve from 0.06566
#
# Epoch 00557: val_loss did not improve from 0.06566
#
# Epoch 00558: val_loss did not improve from 0.06566
#
# Epoch 00559: val_loss did not improve from 0.06566
#
# Epoch 00560: val_loss did not improve from 0.06566
#
# Epoch 00561: val_loss did not improve from 0.06566
#
# Epoch 00562: val_loss did not improve from 0.06566
#
# Epoch 00563: val_loss did not improve from 0.06566
#
# Epoch 00564: val_loss did not improve from 0.06566
#
# Epoch 00565: val_loss did not improve from 0.06566
#
# Epoch 00566: val_loss did not improve from 0.06566
#
# Epoch 00567: val_loss did not improve from 0.06566
# Epoch 00568: val_loss did not improve from 0.06566
#
# Epoch 00569: val_loss did not improve from 0.06566
#
# Epoch 00570: val_loss did not improve from 0.06566
#
# Epoch 00571: val_loss did not improve from 0.06566
#
# Epoch 00572: val_loss did not improve from 0.06566
#
# Epoch 00573: val_loss did not improve from 0.06566
#
# Epoch 00574: val_loss improved from 0.06566 to 0.06437, saving model to ./model/574-0.0644.hdf5
#
# Epoch 00575: val_loss did not improve from 0.06437
#
# Epoch 00576: val_loss did not improve from 0.06437
#
# Epoch 00577: val_loss did not improve from 0.06437
#
# Epoch 00578: val_loss did not improve from 0.06437
#
# Epoch 00579: val_loss did not improve from 0.06437
#
# Epoch 00580: val_loss did not improve from 0.06437
#
# Epoch 00581: val_loss did not improve from 0.06437
#
# Epoch 00582: val_loss did not improve from 0.06437
#
# Epoch 00583: val_loss did not improve from 0.06437
#
# Epoch 00584: val_loss did not improve from 0.06437
#
# Epoch 00585: val_loss did not improve from 0.06437
#
# Epoch 00586: val_loss did not improve from 0.06437
#
# Epoch 00587: val_loss did not improve from 0.06437
#
# Epoch 00588: val_loss did not improve from 0.06437
#
# Epoch 00589: val_loss did not improve from 0.06437
#
# Epoch 00590: val_loss did not improve from 0.06437
#
# Epoch 00591: val_loss did not improve from 0.06437
#
# Epoch 00592: val_loss did not improve from 0.06437
#
# Epoch 00593: val_loss did not improve from 0.06437
#
# Epoch 00594: val_loss did not improve from 0.06437
#
# Epoch 00595: val_loss did not improve from 0.06437
#
# Epoch 00596: val_loss did not improve from 0.06437
#
# Epoch 00597: val_loss did not improve from 0.06437
#
# Epoch 00598: val_loss improved from 0.06437 to 0.06435, saving model to ./model/598-0.0643.hdf5
#
# Epoch 00599: val_loss did not improve from 0.06435
#
# Epoch 00600: val_loss did not improve from 0.06435
#
# Epoch 00601: val_loss did not improve from 0.06435
#
# Epoch 00602: val_loss did not improve from 0.06435
#
# Epoch 00603: val_loss did not improve from 0.06435
#
# Epoch 00604: val_loss did not improve from 0.06435
#
# Epoch 00605: val_loss did not improve from 0.06435
#
# Epoch 00606: val_loss did not improve from 0.06435
#
# Epoch 00607: val_loss improved from 0.06435 to 0.06430, saving model to ./model/607-0.0643.hdf5
#
# Epoch 00608: val_loss did not improve from 0.06430
#
# Epoch 00609: val_loss did not improve from 0.06430
#
# Epoch 00610: val_loss did not improve from 0.06430
#
# Epoch 00611: val_loss improved from 0.06430 to 0.06321, saving model to ./model/611-0.0632.hdf5
#
# Epoch 00612: val_loss did not improve from 0.06321
#
# Epoch 00613: val_loss did not improve from 0.06321
#
# Epoch 00614: val_loss did not improve from 0.06321
#
# Epoch 00615: val_loss did not improve from 0.06321
#
# Epoch 00616: val_loss did not improve from 0.06321
#
# Epoch 00617: val_loss did not improve from 0.06321
#
# Epoch 00618: val_loss improved from 0.06321 to 0.06236, saving model to ./model/618-0.0624.hdf5
#
# Epoch 00619: val_loss did not improve from 0.06236
#
# Epoch 00620: val_loss did not improve from 0.06236
#
# Epoch 00621: val_loss did not improve from 0.06236
#
# Epoch 00622: val_loss did not improve from 0.06236
#
# Epoch 00623: val_loss did not improve from 0.06236
#
# Epoch 00624: val_loss did not improve from 0.06236
#
# Epoch 00625: val_loss improved from 0.06236 to 0.06210, saving model to ./model/625-0.0621.hdf5
#
# Epoch 00626: val_loss did not improve from 0.06210
#
# Epoch 00627: val_loss did not improve from 0.06210
#
# Epoch 00628: val_loss improved from 0.06210 to 0.06168, saving model to ./model/628-0.0617.hdf5
#
# Epoch 00629: val_loss did not improve from 0.06168
#
# Epoch 00630: val_loss did not improve from 0.06168
#
# Epoch 00631: val_loss did not improve from 0.06168
#
# Epoch 00632: val_loss did not improve from 0.06168
#
# Epoch 00633: val_loss did not improve from 0.06168
#
# Epoch 00634: val_loss did not improve from 0.06168
#
# Epoch 00635: val_loss did not improve from 0.06168
#
# Epoch 00636: val_loss did not improve from 0.06168
#
# Epoch 00637: val_loss did not improve from 0.06168
#
# Epoch 00638: val_loss did not improve from 0.06168
#
# Epoch 00639: val_loss did not improve from 0.06168
#
# Epoch 00640: val_loss did not improve from 0.06168
#
# Epoch 00641: val_loss did not improve from 0.06168
#
# Epoch 00642: val_loss improved from 0.06168 to 0.06139, saving model to ./model/642-0.0614.hdf5
#
# Epoch 00643: val_loss did not improve from 0.06139
#
# Epoch 00644: val_loss did not improve from 0.06139
#
# Epoch 00645: val_loss improved from 0.06139 to 0.06064, saving model to ./model/645-0.0606.hdf5
#
# Epoch 00646: val_loss did not improve from 0.06064
#
# Epoch 00647: val_loss did not improve from 0.06064
#
# Epoch 00648: val_loss did not improve from 0.06064
#
# Epoch 00649: val_loss did not improve from 0.06064
#
# Epoch 00650: val_loss did not improve from 0.06064
#
# Epoch 00651: val_loss did not improve from 0.06064
#
# Epoch 00652: val_loss did not improve from 0.06064
#
# Epoch 00653: val_loss did not improve from 0.06064
#
# Epoch 00654: val_loss did not improve from 0.06064
#
# Epoch 00655: val_loss improved from 0.06064 to 0.05910, saving model to ./model/655-0.0591.hdf5
#
# Epoch 00656: val_loss improved from 0.05910 to 0.05575, saving model to ./model/656-0.0558.hdf5
#
# Epoch 00657: val_loss did not improve from 0.05575
#
# Epoch 00658: val_loss did not improve from 0.05575
#
# Epoch 00659: val_loss improved from 0.05575 to 0.05482, saving model to ./model/659-0.0548.hdf5
#
# Epoch 00660: val_loss did not improve from 0.05482
#
# Epoch 00661: val_loss did not improve from 0.05482
#
# Epoch 00662: val_loss improved from 0.05482 to 0.05283, saving model to ./model/662-0.0528.hdf5
#
# Epoch 00663: val_loss did not improve from 0.05283
#
# Epoch 00664: val_loss did not improve from 0.05283
#
# Epoch 00665: val_loss did not improve from 0.05283
#
# Epoch 00666: val_loss did not improve from 0.05283
#
# Epoch 00667: val_loss did not improve from 0.05283
#
# Epoch 00668: val_loss did not improve from 0.05283
#
# Epoch 00669: val_loss did not improve from 0.05283
#
# Epoch 00670: val_loss did not improve from 0.05283
#
# Epoch 00671: val_loss improved from 0.05283 to 0.05274, saving model to ./model/671-0.0527.hdf5
#
# Epoch 00672: val_loss did not improve from 0.05274
#
# Epoch 00673: val_loss did not improve from 0.05274
#
# Epoch 00674: val_loss did not improve from 0.05274
#
# Epoch 00675: val_loss did not improve from 0.05274
#
# Epoch 00676: val_loss did not improve from 0.05274
#
# Epoch 00677: val_loss did not improve from 0.05274
#
# Epoch 00678: val_loss did not improve from 0.05274
#
# Epoch 00679: val_loss did not improve from 0.05274
#
# Epoch 00680: val_loss did not improve from 0.05274
#
# Epoch 00681: val_loss did not improve from 0.05274
#
# Epoch 00682: val_loss did not improve from 0.05274
#
# Epoch 00683: val_loss did not improve from 0.05274
#
# Epoch 00684: val_loss did not improve from 0.05274
#
# Epoch 00685: val_loss did not improve from 0.05274
#
# Epoch 00686: val_loss did not improve from 0.05274
#
# Epoch 00687: val_loss did not improve from 0.05274
#
# Epoch 00688: val_loss did not improve from 0.05274
#
# Epoch 00689: val_loss did not improve from 0.05274
#
# Epoch 00690: val_loss did not improve from 0.05274
#
# Epoch 00691: val_loss did not improve from 0.05274
#
# Epoch 00692: val_loss did not improve from 0.05274
#
# Epoch 00693: val_loss did not improve from 0.05274
#
# Epoch 00694: val_loss did not improve from 0.05274
#
# Epoch 00695: val_loss did not improve from 0.05274
#
# Epoch 00696: val_loss did not improve from 0.05274
#
# Epoch 00697: val_loss did not improve from 0.05274
#
# Epoch 00698: val_loss did not improve from 0.05274
#
# Epoch 00699: val_loss did not improve from 0.05274
#
# Epoch 00700: val_loss did not improve from 0.05274
#
# Epoch 00701: val_loss did not improve from 0.05274
#
# Epoch 00702: val_loss did not improve from 0.05274
#
# Epoch 00703: val_loss did not improve from 0.05274
#
# Epoch 00704: val_loss did not improve from 0.05274
#
# Epoch 00705: val_loss did not improve from 0.05274
#
# Epoch 00706: val_loss did not improve from 0.05274
#
# Epoch 00707: val_loss did not improve from 0.05274
#
# Epoch 00708: val_loss did not improve from 0.05274
#
# Epoch 00709: val_loss did not improve from 0.05274
#
# Epoch 00710: val_loss did not improve from 0.05274
#
# Epoch 00711: val_loss did not improve from 0.05274
#
# Epoch 00712: val_loss did not improve from 0.05274
#
# Epoch 00713: val_loss did not improve from 0.05274
#
# Epoch 00714: val_loss did not improve from 0.05274
#
# Epoch 00715: val_loss did not improve from 0.05274
#
# Epoch 00716: val_loss did not improve from 0.05274
#
# Epoch 00717: val_loss did not improve from 0.05274
#
# Epoch 00718: val_loss did not improve from 0.05274
#
# Epoch 00719: val_loss did not improve from 0.05274
#
# Epoch 00720: val_loss did not improve from 0.05274
#
# Epoch 00721: val_loss did not improve from 0.05274
#
# Epoch 00722: val_loss did not improve from 0.05274
#
# Epoch 00723: val_loss did not improve from 0.05274
#
# Epoch 00724: val_loss did not improve from 0.05274
#
# Epoch 00725: val_loss did not improve from 0.05274
#
# Epoch 00726: val_loss did not improve from 0.05274
#
# Epoch 00727: val_loss did not improve from 0.05274
#
# Epoch 00728: val_loss did not improve from 0.05274
#
# Epoch 00729: val_loss did not improve from 0.05274
#
# Epoch 00730: val_loss did not improve from 0.05274
#
# Epoch 00731: val_loss did not improve from 0.05274
#
# Epoch 00732: val_loss did not improve from 0.05274
#
# Epoch 00733: val_loss did not improve from 0.05274
#
# Epoch 00734: val_loss did not improve from 0.05274
#
# Epoch 00735: val_loss did not improve from 0.05274
#
# Epoch 00736: val_loss did not improve from 0.05274
#
# Epoch 00737: val_loss did not improve from 0.05274
#
# Epoch 00738: val_loss did not improve from 0.05274
#
# Epoch 00739: val_loss did not improve from 0.05274
#
# Epoch 00740: val_loss did not improve from 0.05274
#
# Epoch 00741: val_loss did not improve from 0.05274
#
# Epoch 00742: val_loss did not improve from 0.05274
#
# Epoch 00743: val_loss did not improve from 0.05274
#
# Epoch 00744: val_loss did not improve from 0.05274
#
# Epoch 00745: val_loss did not improve from 0.05274
#
# Epoch 00746: val_loss did not improve from 0.05274
#
# Epoch 00747: val_loss did not improve from 0.05274
#
# Epoch 00748: val_loss did not improve from 0.05274
#
# Epoch 00749: val_loss did not improve from 0.05274
#
# Epoch 00750: val_loss did not improve from 0.05274
#
# Epoch 00751: val_loss did not improve from 0.05274
#
# Epoch 00752: val_loss did not improve from 0.05274
#
# Epoch 00753: val_loss did not improve from 0.05274
#
# Epoch 00754: val_loss did not improve from 0.05274
#
# Epoch 00755: val_loss did not improve from 0.05274
#
# Epoch 00756: val_loss did not improve from 0.05274
#
# Epoch 00757: val_loss did not improve from 0.05274
#
# Epoch 00758: val_loss did not improve from 0.05274
#
# Epoch 00759: val_loss did not improve from 0.05274
#
# Epoch 00760: val_loss did not improve from 0.05274
#
# Epoch 00761: val_loss did not improve from 0.05274
#
# Epoch 00762: val_loss did not improve from 0.05274
#
# Epoch 00763: val_loss did not improve from 0.05274
# Epoch 00764: val_loss did not improve from 0.05274
#
# Epoch 00765: val_loss did not improve from 0.05274
#
# Epoch 00766: val_loss did not improve from 0.05274
#
# Epoch 00767: val_loss did not improve from 0.05274
#
# Epoch 00768: val_loss did not improve from 0.05274
#
# Epoch 00769: val_loss did not improve from 0.05274
#
# Epoch 00770: val_loss did not improve from 0.05274
#
# Epoch 00771: val_loss did not improve from 0.05274

# %%
# y_vloss에 테스트셋으로 실험 결과의 오차 값을 저장
y_vloss = history.history['val_loss']

# %%
# y_acc에 학습셋으로 측정한 정확도의 값을 저장
y_acc = history.history['acc']

# %%
# x값을 지정하고 정확도를 파란색으로, 오차를 빨간색으로 표시
x_len = np.arange(len(y_acc))
plt.plot(x_len, y_vloss, "o", c="red", markersize=3)
plt.plot(x_len, y_acc, "o", c= "blue",markersize=3)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
