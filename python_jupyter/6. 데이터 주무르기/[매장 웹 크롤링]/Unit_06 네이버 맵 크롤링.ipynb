# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import time
import numpy as np
import pandas as pd

driver = webdriver.Chrome(executable_path=r'D:\dudwlsrla92\Python_jupyter_notebook\chromedriver.exe')
driver.implicitly_wait(3)


area = for i in areas
name = ['']

add_name = []
address  = []
for idx in area:
    driver.get('https://map.naver.com/')
    driver.find_element_by_css_selector('#search-input ').send_keys(idx)
    driver.find_element_by_css_selector('#header button[type="submit"]').click()

    
    while True:
        html  = driver.page_source
        soup1 = bs(html, 'html.parser')
        add   = soup1.select('.lsnx_det .addr')
        name  = soup1.select('.lsnx_det a')
        name2 = " ".join(str(x) for x in name)
        soup1 = bs(name2,'lxml')
        a     = soup1.find('a').parent.text
        add_name.append(a)
        
        try : driver.find_element_by_css_selector('.paginate strong+a').click()
        except : break
        time.sleep(1)
        
a = " ".join(str(x) for x in add_name)
a = a.replace('거리뷰','')
a = a.replace('항공뷰','')
a = a.replace('카드','')
a = a.replace('지번','')
a = a.replace('이디야','\t이디야')
a = a.split('\t')
name = pd.DataFrame(a,columns=['Name'])
name["Name"].replace('',np.NaN,inplace=True)
name = name.dropna(how="all")
name
# Out:
#                       Name
# 1            이디야커피랩   가격
# 2    이디야커피 강남역지하상가점 실내뷰
# 3         이디야커피 건대로데오점
# 4       이디야 동서울터미널점   가격
# 5         이디야 영등포역점   가격
# 6         이디야커피 대학로점  가격
# 7        이디야커피 건대역점   가격
# 8         이디야커피 혜화역점  가격
# 9          이디야 수유역점   가격
# 10       이디야커피 홍익대점   가격
# 11       이디야커피 신촌역점   가격
# 12        이디야커피 동대문점  가격
# 13      이디야 강남고속터미널점   가격
# 14         이디야커피사당점   가격
# 15        이디야 연신내역점   가격
# 16        이디야커피 숙대입구역점
# 17            이디야 서교동점
# 18   이디야커피 마곡퀸즈파크9점   가격
# 19     이디야커피 홍대청기와점   가격
# 20     이디야커피 태릉입구역점   가격
# 21     이디야커피 태릉입구역점   가격
# 22           이디야커피 명동역점
# 23        이디야커피 영등포중앙점
# 24          이디야커피 종로3가점
# 25          이디야 노원사거리점
# 26       이디야커피 총신대입구역점
# 27      이디야커피 왕십리역점   가격
# 28            이디야 상수역점
# 29        이디야 홍대서교점   가격
# 30     이디야커피 서울대중앙점   가격
# ..                     ...
# 310        이디야커피 남부지법점
# 311    이디야커피 대전은행동점   가격
# 312           이디야 전민동점
# 313     이디야커피 대전시청점   가격
# 314        이디야 관평동점   가격
# ...

# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import time
import numpy as np
import pandas as pd
from fake_useragent import UserAgent
import requests
ua = UserAgent()

name=[];address=[];roadaddress=[];abbraddress=[];tel=[];x=[];y=[];
for k in range(123):
    url='https://map.naver.com/search2/local.nhn?query=%EC%98%AC%EB%A6%AC%EB%B8%8C%EC%98%81&page='+str(k+1)+'&type=SITE_1&queryRank=1&re=1&siteSort=0&menu=location&searchCoord=126.945975%3B37.5655025&sm=clk&mpx=09410114%3A37.5585674%2C126.9459641%3AZ9%3A0.0531249%2C0.1163489'
    headers={'User-Agent' : ua.random}
    res = requests.get(url = url,headers=headers)
    a=res.json()
    for i in a['result']['site']['list']: 
        a=(i["name"]) ;name.append(a)
        b=(i["address"]);address.append(b)
        c=(i["roadAddress"]);roadaddress.append(c)
        d=(i["abbrAddress"]);abbraddress.append(d)
        e=(i["telDisplay"]);tel.append(e)
        f=(i["x"]) ;x.append(f)
        g=(i["y"]);y.append(g)
    time.sleep(3)

Oliveyoung = pd.DataFrame({'Name':name,'Address':address,'Roadaddress':roadaddress,'AbbrAddress':abbraddress,'Tel':tel,'Longitude':x,'Latitude':y})
Oliveyoung["Roadaddress"].replace('',np.NaN,inplace=True)
Oliveyoung["Tel"].replace('',np.NaN,inplace=True)
Oliveyoung["AbbrAddress"].replace('',np.NaN,inplace=True)
Oliveyoung["Longitude"].replace('',np.NaN,inplace=True)
Oliveyoung["Latitude"].replace('',np.NaN,inplace=True)
Oliveyoung.to_csv('Oliveyoung_json.csv', sep=",",encoding='ms949') #한글이 깨져서 인코딩
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-63d13faeffdf> in <module>
#      14     res = requests.get(url = url,headers=headers)
#      15     a=res.json()
# ---> 16     for i in a['result']['site']['list']:
#      17         a=(i["name"]) ;name.append(a)
#      18         b=(i["address"]);address.append(b)
#
# KeyError: 'result'

# %%
data = {
    'ins_lat':'37.56682', # 지정한 위도와 경도에서 가까운 순으로 나열
    'ins_lng':'126.97865',
    'p_sido_cd':'01', # 01=서울시, 08=경기 ... 16=제주
    'p_gugun_cd':'',  # 세부지역 (지정하지 않으면 시/도 전체)
    'in_biz_cd':'',
    'set_date':'',
    'iend':'1000',
}
    
url = 'https://map.naver.com/search2/local.nhn?sm=hty&searchCoord=127.3576555%3B36.3545808&isFirstSearch=true&query=%EC%84%9C%EC%9A%B8+%EC%9D%B4%EB%94%94%EC%95%BC&menu=location&mpx=07170586%3A36.3545808%2C127.3576555%3AZ11%3A0.0338265%2C0.0060902'
r = requests.post(url, data=data)

r.text[:1000] # 수신된 데이터의 앞부분만 확인
# Out:
# '<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">\n<html><head>\n<title>400 Bad Request</title>\n</head><body>\n<h1>Bad Request</h1>\n<p>Your browser sent a request that this server could not understand.<br />\n</p>\n</body></html>\n'

# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import time
import numpy as np
import pandas as pd

driver = webdriver.Chrome(executable_path=r'D:\dudwlsrla92\Python_jupyter_notebook\chromedriver.exe')
driver.implicitly_wait(3)

area = ['서울 이디야']

add_name = []
address  = []
for idx in area:
    driver.get('https://map.naver.com/')
    driver.find_element_by_css_selector('#search-input ').send_keys(idx)
    driver.find_element_by_css_selector('#header button[type="submit"]').click()
    driver.find_element_by_css_selector('.sa_lst _sub_region_lists').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-40-a57b68a7098e> in <module>
#      16     driver.find_element_by_css_selector('#search-input ').send_keys(idx)
#      17     driver.find_element_by_css_selector('#header button[type="submit"]').click()
# ---> 18     driver.find_element_by_css_selector('.sa_lst _sub_region_lists').click()
#      19
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
# ...
