# %% [markdown]
# # ["커피 지수"와 도시의 발전 수준]

# %% [markdown]
# # <span style='color:teal'>1. 스타벅스(Starbucks) 매장 데이터</span>
# - https://financedata.github.io/posts/python_starbucks_map.html

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
data = {
    'ins_lat':'37.56682', # 지정한 위도와 경도에서 가까운 순으로 나열
    'ins_lng':'126.97865',
    'p_sido_cd':'01', # 01=서울시, 08=경기 ... 16=제주
    'p_gugun_cd':'',  # 세부지역 (지정하지 않으면 시/도 전체)
    'in_biz_cd':'',
    'set_date':'',
    'iend':'1000',
}
    
url = 'https://www.istarbucks.co.kr/store/getStore.do'
r = requests.post(url, data=data)

r.text[:1000] # 수신된 데이터의 앞부분만 확인
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-34eeff4e3494> in <module>
#       2
#       3 url = 'https://www.istarbucks.co.kr/store/getStore.do'
# ----> 4 r = requests.post(url, data=data)
#       5
#       6 r.text[:1000] # 수신된 데이터의 앞부분만 확인
#
# NameError: name 'requests' is not defined

# %%
{
  "list": [
      {
            // ... 중략 ...
            "s_code": "1311",
            "s_name": "방화DT",
            "tel": "02-2664-3480",
            "fax": "02-2664-3481",
            "sido_code": "01",
            "sido_name": "서울",
            "gugun_code": "0103",
            "gugun_name": "강서구",
            "addr": "서울특별시 강서구 방화동 293-4",
            "park_info": null,
            "new_state": null,
            "theme_state": "T17@T16@T09@T20@T01@T05@T08@T04",
            // ... 중략 ...
            "lat": "37.574339",
            "lot": "126.816415",
            "t22": 0
        },
        {
            // ... 중략 ...
            "s_code": "1267",
            "s_name": "마곡나루역",
            "tel": "02-3662-3504",
            "fax": "02-3662-3505",
            "sido_code": "01",
            "sido_name": "서울",
            "gugun_code": "0103",
            "gugun_name": "강서구",
            "addr": "서울특별시 강서구 마곡동 759-3 보타닉파크타워Ⅰ105,203,204호",
            "park_info": null,
            "new_state": null,
            "theme_state": "T08@T05@T04@T17@T16@P80@T20",
            // ... 중략 ...
            "lat": "37.56813",
            "lot": "126.82614",
            "t22": 0
        },
    ]
 }

# %%
jo = json.loads(r.text)
df = json_normalize(jo, 'list')

# %%
# 행(row)수, 서울 457개 매장
len(df)
# Out:
# 496

# %%
# 컬럼수 111개
df.columns
# Out:
# Index(['addr', 'addr_search_cnt', 'address', 'all_search_cnt', 'code_order',
#        'cold_blew', 'defaultimage', 'disp', 'doro_address', 'espresso',
#        ...
#        't10', 't12', 't20', 't21', 't22', 'tel', 'theme_state', 'vSal',
#        'view_yn', 'whcroad_yn'],
#       dtype='object', length=119)

# %%
# 주요한 컬럼 몇 가지 선택
               
df = df[['s_name', 'lat', 'lot', 'sido_name', 'gugun_name', 'doro_address', 'tel']]
df.head(20)
# Out:
#        s_name         lat         lot sido_name gugun_name  \
# 0     역삼아레나빌딩   37.501087  127.043069        서울        강남구
# 1      논현역사거리   37.510178  127.022223        서울        강남구
# 2      국기원사거리   37.499517  127.031495        서울        강남구
# 3     대치대원빌딩R   37.494668  127.062583        서울        강남구
# 4    삼성역섬유센터R   37.507750  127.060651        서울        강남구
# 5        압구정R  37.5273669  127.033061        서울        강남구
# 6        수서역R   37.488008  127.102650        서울        강남구
# 7     양재강남빌딩R   37.485192  127.036685        서울        강남구
# 8     선릉동신빌딩R   37.505321  127.050409        서울        강남구
# 9     봉은사로선정릉   37.511293  127.048409        서울        강남구
# 10      강남오거리   37.502117  127.026672        서울        강남구
# 11  스타필드코엑스몰R    37.50999  127.061455        서울        강남구
# 12     강남구청정문   37.518181  127.045995        서울        강남구
# 13       도곡공원   37.492805  127.041309        서울        강남구
# 14        강남R   37.497711  127.028439        서울        강남구
# 15    대치은마사거리   37.498973  127.060172        서울        강남구
# 16     청담영동대로   37.522156  127.056449        서울        강남구
# 17        압구정   37.526283  127.029560        서울        강남구
# 18      신사가로수   37.521852  127.022510        서울        강남구
# 19      청담스타R   37.525216  127.041827        서울        강남구
#
#                   doro_address           tel
# 0      서울특별시 강남구 언주로 425 (역삼동)   02-568-3762
# 1     서울특별시 강남구 강남대로 538 (논현동)  02-3442-3672
# 2     서울특별시 강남구 테헤란로 125 (역삼동)   02-568-3668
# 3   서울특별시 강남구 남부순환로 2947 (대치동)   02-568-3704
# 4     서울특별시 강남구 테헤란로 518 (대치동)   02-568-3648
# 5      서울특별시 강남구 언주로 861 (신사동)   02-541-3622
# 6      서울특별시 강남구 광평로 281 (수서동)  02-6181-3688
# 7   서울특별시 강남구 남부순환로 2621 (도곡동)   02-571-3604
# 8     서울특별시 강남구 테헤란로 409 (삼성동)  02-2051-3562
# 9     서울특별시 강남구 봉은사로 446 (삼성동)   02-539-3564
# 10   서울특별시 강남구 봉은사로2길 39 (역삼동)   02-557-3484
# 11    서울특별시 강남구 영동대로 513 (삼성동)  02-6002-3467
# 12     서울특별시 강남구 학동로 419 (청담동)   02-514-3397
# 13     서울특별시 강남구 도곡로 205 (역삼동)   02-565-3496
# 14    서울특별시 강남구 강남대로 390 (역삼동)   02-561-3478
# 15     서울특별시 강남구 도곡로 457 (대치동)   02-554-3315
# 16    서울특별시 강남구 영동대로 720 (청담동)  02-3443-3371
# 17  서울특별시 강남구 압구정로30길 17 (신사동)   02-541-3306
# 18  서울특별시 강남구 압구정로12길 32 (신사동)  02-3446-3356
# 19  서울특별시 강남구 도산대로57길 24 (청담동)   02-514-3364

# %%
df.dtypes
# Out:
# s_name          object
# lat             object
# lot             object
# sido_name       object
# gugun_name      object
# doro_address    object
# tel             object
# dtype: object

# %%
df['lat'] = df['lat'].astype(float)
df['lot'] = df['lot'].astype(float)

# %%
df.dtypes
# Out:
# s_name           object
# lat             float64
# lot             float64
# sido_name        object
# gugun_name       object
# doro_address     object
# tel              object
# dtype: object

# %%
df[df['s_name'] == '시청'] # 시청점
# Out:
#     s_name       lat         lot sido_name gugun_name  \
# 427     시청  37.56629  126.979808        서울         중구
#
#                              doro_address          tel
# 427  서울특별시 중구 을지로 19, 삼성화재삼성빌딩 1층 (을지로1가)  02-758-8504

# %%
import folium

# 서울 시청 
map_osm = folium.Map(location=(37.56629, 126.979808))
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 확대 지정 (zoom_start)
map_osm = folium.Map(location=(37.56629, 126.979808), zoom_start=17)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도 tiles 지정
map_osm = folium.Map(location=(37.56629, 126.979808), zoom_start=17, tiles='Stamen Toner')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
시청_좌표=(37.56629, 126.979808)
 
map_osm = folium.Map(location=시청_좌표, zoom_start=17)
folium.Marker(시청_좌표, popup='시청').add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm = folium.Map(location=시청_좌표, zoom_start=11)

for ix, row in df.iterrows():
    location = (row['lat'], row['lot'])
    folium.Marker(location, popup=row['s_name']).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

한라산_좌표 = (33.361666, 126.529166)

data = {
    'ins_lat': '33.4996213', # 제주 시청의 좌표
    'ins_lng': '126.5311884',
    'p_sido_cd':'16', # 01=서울시, 08=경기 ... 16=제주
    'p_gugun_cd':'',  # 세부지역 (지정하지 않으면 시/도 전체)
    'in_biz_cd':'',
    'set_date':'',
    'iend':'1000',
}
    
url = 'https://www.istarbucks.co.kr/store/getStore.do'
r = requests.post(url, data=data)
df = json_normalize(json.loads(r.text), 'list')

map_osm = folium.Map(location=한라산_좌표, zoom_start=10)
for ix, row in df.iterrows():
    location = (row['lat'], row['lot'])
    folium.Marker(location, popup=row['s_name']).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # <span style='color:teal'>2. Coffee Bean </span>

# %%
# Out:
# '<!DOCTYPE html>\r\n\r\n<!--[if IE 6]> <html class="no-js lt-ie10 lt-ie9 lt-ie8 ie6" lang="ko-KR"> <![endif]-->\r\n<!--[if IE 7]> <html class="no-js lt-ie10 lt-ie9 lt-ie8 ie7" lang="ko-KR"> <![endif]-->\r\n<!--[if IE 8]> <html class="no-js lt-ie10 lt-ie9 ie8" lang="ko-KR"> <![endif]-->\r\n<!--[if IE 9]> <html class="no-js lt-ie10 ie9" lang="ko-KR"> <![endif]-->\r\n<!--[if gt IE 9]><!--> <html class="no-js" lang="ko-KR"> <!--<![endif]-->\r\n<head>\r\n\r\n\t<meta charset="UTF-8">\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1">\r\n\r\n<title>STORE | COFFEE BEAN KOREA</title><meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no, target-densitydpi=medium-dpi">\r\n<link rel="shortcut icon" type="image/x-icon" href="/images/favicon.ico?v=1" />\r\n\r\n\t<link rel="stylesheet" href="/css/pages/import.css?v=20170406">\r\n\t<script src="/js/common/libs/modernizr.custom.js"></script>\t\r\n\t<script src="/js/common/libs/greensock/TweenMax.min.js"><'

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-31-0641158ef799> in <module>
# ----> 1 jo = json.loads(r.text)
#       2 df = json_normalize(jo, 'list')
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# # <span style='color:teal'>3. Ediya</span>

# %% [markdown]
# # <span style='color:teal'>4. 빽다방</span>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
html = urlopen("http://www.naver.com")  
bsObject = BeautifulSoup(html, "html.parser")
